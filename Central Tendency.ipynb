# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()

### returns the properties of the given dataset 
### rows X columns , datatype , data count , column names etc
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
## Quan=["ssc_p","hsc_p","etest_p","degree_p","mba_p","salary"]

## Qual=["gender","ssc_b","hsc_b","degree_t"]

### Quantitative data columns are stored in Quan 

### Qualitative data columns are stored in Qual

# %%
dataset.columns   ## returns the column names
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dir(dataset)

### built in function that returns all the attributes , methods associated with the dataset
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
dataset.dtypes

###dtypes - returns datatypes of all the columns
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
dataset["gender"].dtypes

## returns the datatype of a specific column "gender"
# Out:
# dtype('O')

# %%
dataset["ssc_p"].dtypes
# Out:
# dtype('float64')

# %%
### creating a loop to print all the column names in the dataset

for columnname in dataset.columns:
    print(columnname)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
### logic to check if a specific column is quan or qual

if(dataset["ssc_p"].dtype=='O'):
    print("qual")
else:
    print("quan")
# Out:
# quan

# %%
if(dataset["gender"].dtype=='O'):
    print("qual")
else:
    print("quan")
# Out:
# qual

# %%
### Creating a loop with logic to check the datatype of all the columns and return the column name with its type

quan=[]
qual=[]
for columnname in dataset.columns:
    print(columnname)
    if(dataset[columnname].dtype=='O'):
       ### print("qual")
        qual.append(columnname)
    else:
       ### print("quan")
        quan.append(columnname)


#### append function - adds the elements to the list specified ( qual , quan )
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
####  Creating a function to separate Qualitative and Quantitative columns

def QuanQual(dataset):
    quan=[]
    qual=[]
    for columnname in dataset.columns:
    ###print(columnname)
        if(dataset[columnname].dtype=='O'):
    ### print("qual")
            qual.append(columnname)
        else:
    ### print("quan")
            quan.append(columnname)
    return quan,qual

# %%
QuanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
### Returning the list to the variables separately in Quan & Qual 

Quan,Qual=QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# #### Central Tendency

# %%
dataset["ssc_p"].mean()

### to find the mean of specific column(data)
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()
# Out:
# 67.0

# %%
dataset["ssc_p"].mode()
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
dataset.describe()

### returns all the metrics like mean standard deviation etc of quantitative data columns
### It doesnt include median , mode 
### Median , Mode - are importatnt metrics to evaluate if a dataset has outliers or not.
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame()     

### We are creating a table with all the required metrics and saving it as "descriptive"

# %%
descriptive

### It returns a single line only as the Index (Rows & Columns ) are not defined in the dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive=pd.DataFrame(index=["Mean", "Median","Mode"],columns=Quan)

### Specifying the rows as required metric names and column names as quantitative columns (quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["hsc_p"]["Median"]=0

 #### Accessing one specific cell (hsc_p X Median )and assigning value as "0" 
 #### Indexing Column/ Row
# Out:
# /var/folders/jc/s6dgsbyn6fj3tn0yptft26580000gn/T/ipykernel_2210/2543987478.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive["hsc_p"]["Median"]=0

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN     0      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
#### Once we know how to access 1 cell we can access all the cells and assign the respective data from the dataset

# %%
descriptive=pd.DataFrame(index=["Mean", "Median","Mode"],columns=quan)
for columnname in quan:
    descriptive[columnname]["Mean"]=dataset[columnname].mean()
    descriptive[columnname]["Median"]=dataset[columnname].median()
    descriptive[columnname]["Mode"]=dataset[columnname].mode()[0]
# Out:
# /var/folders/jc/s6dgsbyn6fj3tn0yptft26580000gn/T/ipykernel_2210/870889953.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnname]["Mean"]=dataset[columnname].mean()
# ...

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %%
descriptive=pd.DataFrame(index=["Mean", "Median","Mode"],columns=quan)
for columnname in quan:
    descriptive[columnname]["Mean"]=dataset[columnname].mean()
    descriptive[columnname]["Median"]=dataset[columnname].median()
    descriptive[columnname]["Mode"]=dataset[columnname].mode()[0]


##### mode() - returns the value of mode and datatype columnname etc. so we have to add an argument [0] so that it returns only the mode value
# Out:
# /var/folders/jc/s6dgsbyn6fj3tn0yptft26580000gn/T/ipykernel_2210/501945100.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnname]["Mean"]=dataset[columnname].mean()
# ...

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# #### Percentile

# %%
import numpy as np

# %%
np.percentile(dataset["ssc_p"],10)

#### finding the 10th percentile onf the ssc_p column
# Out:
# np.float64(52.0)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%"],columns=quan)
for columnname in quan:
    descriptive.loc["Mean",columnname]=dataset[columnname].mean()
    descriptive.loc["Median",columnname]=dataset[columnname].median()
    descriptive.loc["Mode",columnname]=dataset[columnname].mode()[0]
    descriptive.loc["Q1:25%",columnname]=dataset[columnname].quantile(0.25)
    descriptive.loc["Q2:50%",columnname]=dataset[columnname].quantile(0.50)
    descriptive.loc["Q3:75%",columnname]=dataset[columnname].quantile(0.75)
    descriptive.loc["99%",columnname]=np.percentile(dataset[columnname],99)
    descriptive.loc["Q4:100%",columnname]=dataset[columnname].quantile(1.00)

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# 99%                NaN
# Q4:100%       940000.0

# %% [markdown]
# ###### InterQuartile Range

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnname in quan:
    descriptive.loc["Mean",columnname]=dataset[columnname].mean()
    descriptive.loc["Median",columnname]=dataset[columnname].median()
    descriptive.loc["Mode",columnname]=dataset[columnname].mode()[0]
    descriptive.loc["Q1:25%",columnname]=dataset[columnname].quantile(0.25)
    descriptive.loc["Q2:50%",columnname]=dataset[columnname].quantile(0.50)
    descriptive.loc["Q3:75%",columnname]=dataset[columnname].quantile(0.75)
    descriptive.loc["99%",columnname]=np.percentile(dataset[columnname],99)
    descriptive.loc["Q4:100%",columnname]=dataset[columnname].quantile(1.00)

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR         NaN        NaN        NaN        NaN        NaN        NaN
# 1.5rule     NaN        NaN        NaN        NaN        NaN        NaN
# Lesser      NaN        NaN        NaN        NaN        NaN        NaN
# Greater     NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
##### the rows have been added however the values are not calculated and assigned so its specified as NaN

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnname in quan:
    descriptive.loc["Mean",columnname]=dataset[columnname].mean()
    descriptive.loc["Median",columnname]=dataset[columnname].median()
    descriptive.loc["Mode",columnname]=dataset[columnname].mode()[0]
    descriptive.loc["Q1:25%",columnname]=dataset[columnname].quantile(0.25)
    descriptive.loc["Q2:50%",columnname]=dataset[columnname].quantile(0.50)
    descriptive.loc["Q3:75%",columnname]=dataset[columnname].quantile(0.75)
    descriptive.loc["99%",columnname]=np.percentile(dataset[columnname],99)
    descriptive.loc["Q4:100%",columnname]=dataset[columnname].quantile(1.00)
    descriptive.loc["IQR",columnname]=descriptive[columnname]["Q3:75%"]-descriptive[columnname]["Q1:25%"]
    descriptive.loc["1.5rule",columnname]=1.5*descriptive[columnname]["IQR"]
    descriptive.loc["Lesser",columnname]=descriptive[columnname]["Q1:25%"]-descriptive[columnname]["1.5rule"]
    descriptive.loc["Greater",columnname]=descriptive[columnname]["Q3:75%"]+descriptive[columnname]["1.5rule"]
    descriptive.loc["Min",columnname]=dataset[columnname].min()
    descriptive.loc["Max",columnname]=dataset[columnname].max()

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
descriptive["hsc_p"]["Lesser"]<descriptive["hsc_p"]["Min"]
# Out:
# np.False_

# %%
descriptive["hsc_p"]["Min"]<descriptive["hsc_p"]["Lesser"]
# Out:
# np.True_

# %%
lesser=[]
greater=[]

for columnName in Quan:
    if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# ['hsc_p']

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %% [markdown]
# ##### lesser has the column names that has lower outliers ; greater has the column names that has greater outlier

# %%
for columnName in lesser :
    dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]


#### Replacing the outlier values in respective columns with the lesser / greater values
# Out:
# /var/folders/jc/s6dgsbyn6fj3tn0yptft26580000gn/T/ipykernel_2210/1263614067.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnname in quan:
    descriptive.loc["Mean",columnname]=dataset[columnname].mean()
    descriptive.loc["Median",columnname]=dataset[columnname].median()
    descriptive.loc["Mode",columnname]=dataset[columnname].mode()[0]
    descriptive.loc["Q1:25%",columnname]=dataset[columnname].quantile(0.25)
    descriptive.loc["Q2:50%",columnname]=dataset[columnname].quantile(0.50)
    descriptive.loc["Q3:75%",columnname]=dataset[columnname].quantile(0.75)
    descriptive.loc["99%",columnname]=np.percentile(dataset[columnname],99)
    descriptive.loc["Q4:100%",columnname]=dataset[columnname].quantile(1.00)
    descriptive.loc["IQR",columnname]=descriptive[columnname]["Q3:75%"]-descriptive[columnname]["Q1:25%"]
    descriptive.loc["1.5rule",columnname]=1.5*descriptive[columnname]["IQR"]
    descriptive.loc["Lesser",columnname]=descriptive[columnname]["Q1:25%"]-descriptive[columnname]["1.5rule"]
    descriptive.loc["Greater",columnname]=descriptive[columnname]["Q3:75%"]+descriptive[columnname]["1.5rule"]
    descriptive.loc["Min",columnname]=dataset[columnname].min()
    descriptive.loc["Max",columnname]=dataset[columnname].max()

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
lesser=[]
greater=[]

for columnName in Quan:
    if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
##### After replacing the outlier values in the columns when we check for the outliers , it returns no values
##### Hence the outlier values have been replaced successfully.

# %% [markdown]
# ###### Frequency / Relative Frequency / Cumulative Frequency

# %%
dataset["hsc_p"].value_counts()


#### syntax to find the number of counts each data has been presented in the dataset.( Frequency of data )
#### It returns Unique Value ( Index ) & Frequency (Value Counts)
# Out:
# hsc_p
# 63.00    14
# 62.00    12
# 60.00     9
# 67.00     9
# 70.00     8
#          ..
# 70.29     1
# 83.83     1
# 70.40     1
# 90.90     1
# 61.33     1
# Name: count, Length: 91, dtype: int64

# %%
dataset["hsc_p"].value_counts().sort_values()

#### sort the list according to the value counts
# Out:
# hsc_p
# 65.50     1
# 71.98     1
# 69.00     1
# 91.00     1
# 72.50     1
#          ..
# 70.00     8
# 67.00     9
# 60.00     9
# 62.00    12
# 63.00    14
# Name: count, Length: 91, dtype: int64

# %%
dataset["ssc_p"].value_counts().sort_index()

#### sort the list according to the unique value ( index)
# Out:
# ssc_p
# 40.89    1
# 41.00    1
# 43.00    1
# 44.00    1
# 45.00    1
#         ..
# 85.80    1
# 86.50    1
# 87.00    3
# 88.00    1
# 89.40    1
# Name: count, Length: 103, dtype: int64

# %%
freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative_Frequency","CumSum"])

# %%
freqTable
# Out:
# Empty DataFrame
# Columns: [Unique_Values, Frequency, Relative_Frequency, CumSum]
# Index: []

# %%
freqTable["Unique_Values"]=dataset["ssc_p"].value_counts().index
freqTable["Frequency"]=dataset["ssc_p"].value_counts().values
freqTable["Relative_Frequency"]=(freqTable["Frequency"]/103)
freqTable["CumSum"]=freqTable["Relative_Frequency"].cumsum()

# %%
freqTable
# Out:
#      Unique_Values  Frequency  Relative_Frequency    CumSum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
def freqTable(columnName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_Values","Frequency","Relative_Frequency","CumSum"])
    freqTable["Unique_Values"]=dataset[columnName].value_counts().index
    freqTable["Frequency"]=dataset[columnName].value_counts().values
    freqTable["Relative_Frequency"]=(freqTable["Frequency"]/103)
    freqTable["CumSum"]=freqTable["Relative_Frequency"].cumsum()
    return freqTable

##### creating a function to calculate all the parameters ( freq , relative freq , cumsum ) for all the columns

# %%
freqTable("ssc_p",dataset)

###### When calling the function - specify the columnname
# Out:
#      Unique_Values  Frequency  Relative_Frequency    CumSum
# 0            62.00         11            0.106796  0.106796
# 1            63.00         10            0.097087  0.203883
# 2            67.00          9            0.087379  0.291262
# 3            52.00          9            0.087379  0.378641
# 4            73.00          9            0.087379  0.466019
# ..             ...        ...                 ...       ...
# 98           69.70          1            0.009709  2.048544
# 99           80.92          1            0.009709  2.058252
# 100          83.00          1            0.009709  2.067961
# 101          86.50          1            0.009709  2.077670
# 102          80.60          1            0.009709  2.087379
#
# [103 rows x 4 columns]

# %%
def Univariate(dataset,Quan):
    descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
    for columnname in quan:
        descriptive.loc["Mean",columnname]=dataset[columnname].mean()
        descriptive.loc["Median",columnname]=dataset[columnname].median()
        descriptive.loc["Mode",columnname]=dataset[columnname].mode()[0]
        descriptive.loc["Q1:25%",columnname]=dataset[columnname].quantile(0.25)
        descriptive.loc["Q2:50%",columnname]=dataset[columnname].quantile(0.50)
        descriptive.loc["Q3:75%",columnname]=dataset[columnname].quantile(0.75)
        descriptive.loc["99%",columnname]=np.percentile(dataset[columnname],99)
        descriptive.loc["Q4:100%",columnname]=dataset[columnname].quantile(1.00)
        descriptive.loc["IQR",columnname]=descriptive[columnname]["Q3:75%"]-descriptive[columnname]["Q1:25%"]
        descriptive.loc["1.5rule",columnname]=1.5*descriptive[columnname]["IQR"]
        descriptive.loc["Lesser",columnname]=descriptive[columnname]["Q1:25%"]-descriptive[columnname]["1.5rule"]
        descriptive.loc["Greater",columnname]=descriptive[columnname]["Q3:75%"]+descriptive[columnname]["1.5rule"]
        descriptive.loc["Min",columnname]=dataset[columnname].min()
        descriptive.loc["Max",columnname]=dataset[columnname].max()
    return descriptive

# %%
Univariate(dataset,Quan)
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean      108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median    108.0       67.0       65.0       66.0       71.0       62.0
# Mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100%   215.0       89.4      91.15       88.5       98.0      77.89
# IQR       107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule   160.5      22.65      18.15       16.5      35.25     12.465
# Lesser   -106.0      37.95      42.75       44.5      24.75      45.48
# Greater   322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
def find_Outliers(descriptive,Quan):
    lesser=[]
    greater=[]

    for columnName in Quan:
        if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
            lesser.append(columnName)
        if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
            greater.append(columnName)
    return lesser,greater

# %%
find_Outliers(descriptive,Quan)
# Out:
# ([], [])

# %%
def replace_Outliers(descriptive,Quan):
    for columnName in lesser :
        dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
    for columnName in greater:
        dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]
    return

# %%
replace_Outliers(descriptive,Quan)
